# %% [markdown]
# # **This is your first MiPasa Live Article 67!**
#
# ## **Create a live MiPasa article in a few simple steps:**
#
# 1. **Plan**
# 2. **Add explanations/steps**
# 3. **Embed some data**
# 4. **Code**
# 5. **Run**
# 6. **Share!**

# %%
print('Your first code section goes here')
# Out:
# Your first code section goes here
